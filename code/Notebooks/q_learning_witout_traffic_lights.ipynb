# %%
pip install traci
# Out:
# Requirement already satisfied: traci in /usr/local/lib/python3.10/dist-packages (1.21.0)
# Requirement already satisfied: sumolib>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from traci) (1.21.0)

# %%
# !apt-get update
# !apt-get install sumo sumo-tools sumo-doc
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# sumo is already the newest version (1.12.0+dfsg1-1).
# sumo-doc is already the newest version (1.12.0+dfsg1-1).
# sumo-tools is already the newest version (1.12.0+dfsg1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.

# %%
import os
import numpy as np
import traci
import matplotlib.pyplot as plt

# Q-Learning Parameters
ALPHA = 0.1  # Learning rate
GAMMA = 0.9  # Discount factor
EPSILON = 0.1  # Exploration-exploitation balance
EPSILON_DECAY = 0.99
MIN_EPSILON = 0.01
MAX_EPISODES = 200
MAX_STEPS = 1000
NUM_ACTIONS = 2  # Number of actions (e.g., 0: Increase ramp speed, 1: Decrease ramp speed)

# Environment Setup
SUMO_CMD = ["sumo", "-c", "/content/simulation.sumocfg"]

# State representation function
def get_state():
    highway_density = traci.edge.getLastStepVehicleNumber("highway")
    ramp_queue = traci.lane.getLastStepHaltingNumber("ramp_0")
    return (highway_density, ramp_queue)

# Discretize state space (example)
def discretize_state(highway_density, ramp_queue):
    highway_bucket = min(highway_density // 5, 19)  # Increase granularity
    ramp_bucket = min(ramp_queue // 1, 19)  # Increase granularity
    return highway_bucket * 20 + ramp_bucket

# Reward function
def compute_reward(highway_density, ramp_queue):
    throughput = traci.edge.getLastStepVehicleNumber("highway")
    waiting_penalty = ramp_queue * 2
    return throughput - waiting_penalty  # Reward throughput, penalize queue

# Step function to advance the simulation
def step_simulation(action):
    if action == 0:
        # Decrease speed by setting the max speed of the edge the ramp belongs to
        # Get the lane ID of the ramp (instead of the edge ID)
        lane_id = "ramp_0"
        current_speed = traci.lane.getMaxSpeed(lane_id)  # Get current speed of the lane
        traci.lane.setMaxSpeed(lane_id, max(1.0, current_speed - 1.0))
    elif action == 1:
        # Increase speed by setting the max speed of the edge the ramp belongs to
        # Get the lane ID of the ramp (instead of the edge ID)
        lane_id = "ramp_0"
        current_speed = traci.lane.getMaxSpeed(lane_id)  # Get current speed of the lane
        traci.lane.setMaxSpeed(lane_id, current_speed + 1.0)

    traci.simulationStep()
    highway_density = traci.edge.getLastStepVehicleNumber("highway")
    ramp_queue = traci.lane.getLastStepHaltingNumber("ramp_0")
    next_state = discretize_state(highway_density, ramp_queue)
    reward = compute_reward(highway_density, ramp_queue)
    done = traci.simulation.getMinExpectedNumber() == 0

    return next_state, reward, done

# Training loop
def train_q_learning():
    Q_table = np.zeros((400, NUM_ACTIONS))  # State-action space with 400 discrete states
    rewards_per_episode = []

    for episode in range(MAX_EPISODES):
        traci.start(SUMO_CMD)
        state = discretize_state(*get_state())
        total_reward = 0

        global EPSILON
        for step in range(MAX_STEPS):
            if np.random.uniform(0, 1) < EPSILON:
                action = np.random.randint(0, NUM_ACTIONS)  # Explore
            else:
                action = np.argmax(Q_table[state])  # Exploit

            next_state, reward, done = step_simulation(action)
            total_reward += reward

            # Q-Learning update rule
            Q_table[state, action] = Q_table[state, action] + ALPHA * (
                reward + GAMMA * np.max(Q_table[next_state]) - Q_table[state, action]
            )

            state = next_state
            if done:
                break

        rewards_per_episode.append(total_reward)
        EPSILON = max(MIN_EPSILON, EPSILON * EPSILON_DECAY)  # Decay epsilon
        print(f"Episode {episode + 1}/{MAX_EPISODES} - Total Reward: {total_reward}")
        traci.close()

    np.save("/content/q_table_witout_traffic_lights.npy", Q_table)
    return rewards_per_episode  # Return rewards_per_episode

    # Visualization: Total Reward per Episode
    plt.figure()
    plt.plot(range(MAX_EPISODES), rewards_per_episode)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Total Reward per Episode")
    plt.show()

# Policy evaluation function
def evaluate_policy():
    Q_table = np.load("q_table_witout_traffic_lights.npy")
    traci.start(SUMO_CMD)
    state = discretize_state(*get_state())
    total_reward = 0
    total_ramp_waiting_time = 0
    total_vehicle_throughput = 0
    step = 0

    while step < MAX_STEPS:
        action = np.argmax(Q_table[state])
        next_state, reward, done = step_simulation(action)
        total_reward += reward

        # Collect metrics
        ramp_waiting_time = traci.lane.getWaitingTime("ramp_0")
        total_ramp_waiting_time += ramp_waiting_time
        highway_throughput = traci.edge.getLastStepVehicleNumber("highway")
        ramp_throughput = traci.lane.getLastStepVehicleNumber("ramp_0")
        total_vehicle_throughput += (highway_throughput + ramp_throughput)

        state = next_state
        step += 1

        if done:
            break

    traci.close()

    avg_ramp_waiting_time = total_ramp_waiting_time / step
    avg_vehicle_throughput = total_vehicle_throughput / step

    print(f"Evaluation Total Reward: {total_reward}")
    print(f"Average Ramp Waiting Time: {avg_ramp_waiting_time:.2f} seconds")
    print(f"Traffic Flow Efficiency (Vehicles/hour): {avg_vehicle_throughput:.2f}")

    # Visualization: Metrics
    metrics = [total_reward, avg_ramp_waiting_time, avg_vehicle_throughput]
    metric_names = ["Total Reward", "Avg Ramp Waiting Time (s)", "Traffic Flow Efficiency"]

    plt.figure()
    plt.bar(metric_names, metrics)
    plt.title("Policy Evaluation Metrics")
    plt.show()

if __name__ == "__main__":
    rewards_per_episode = train_q_learning()
    evaluate_policy()
# Out:
#  Retrying in 1 seconds
# Episode 1/200 - Total Reward: 774
#  Retrying in 1 seconds
# Episode 2/200 - Total Reward: 604
#  Retrying in 1 seconds
# Episode 3/200 - Total Reward: 1066
#  Retrying in 1 seconds
# Episode 4/200 - Total Reward: 1326
#  Retrying in 1 seconds
# Episode 5/200 - Total Reward: 1235
#  Retrying in 1 seconds
# Episode 6/200 - Total Reward: 1156
#  Retrying in 1 seconds
# Episode 7/200 - Total Reward: 632
#  Retrying in 1 seconds
# Episode 8/200 - Total Reward: 1252
#  Retrying in 1 seconds
# Episode 9/200 - Total Reward: 1446
#  Retrying in 1 seconds
# Episode 10/200 - Total Reward: 1413
#  Retrying in 1 seconds
# Episode 11/200 - Total Reward: 1093
#  Retrying in 1 seconds
# Episode 12/200 - Total Reward: 1052
#  Retrying in 1 seconds
# Episode 13/200 - Total Reward: 1153
#  Retrying in 1 seconds
# Episode 14/200 - Total Reward: 1433
#  Retrying in 1 seconds
# Episode 15/200 - Total Reward: 1399
#  Retrying in 1 seconds
# Episode 16/200 - Total Reward: 1494
#  Retrying in 1 seconds
# Episode 17/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 18/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 19/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 20/200 - Total Reward: 988
#  Retrying in 1 seconds
# Episode 21/200 - Total Reward: 1523
#  Retrying in 1 seconds
# Episode 22/200 - Total Reward: 1534
#  Retrying in 1 seconds
# Episode 23/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 24/200 - Total Reward: 1402
#  Retrying in 1 seconds
# Episode 25/200 - Total Reward: 1126
#  Retrying in 1 seconds
# Episode 26/200 - Total Reward: 1140
#  Retrying in 1 seconds
# Episode 27/200 - Total Reward: 1478
#  Retrying in 1 seconds
# Episode 28/200 - Total Reward: 1355
#  Retrying in 1 seconds
# Episode 29/200 - Total Reward: 1416
#  Retrying in 1 seconds
# Episode 30/200 - Total Reward: 1366
#  Retrying in 1 seconds
# Episode 31/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 32/200 - Total Reward: 1397
#  Retrying in 1 seconds
# Episode 33/200 - Total Reward: 1293
#  Retrying in 1 seconds
# Episode 34/200 - Total Reward: 1372
#  Retrying in 1 seconds
# Episode 35/200 - Total Reward: 1491
#  Retrying in 1 seconds
# Episode 36/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 37/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 38/200 - Total Reward: 1431
#  Retrying in 1 seconds
# Episode 39/200 - Total Reward: 1362
#  Retrying in 1 seconds
# Episode 40/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 41/200 - Total Reward: 1511
#  Retrying in 1 seconds
# Episode 42/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 43/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 44/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 45/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 46/200 - Total Reward: 1578
#  Retrying in 1 seconds
# Episode 47/200 - Total Reward: 1476
#  Retrying in 1 seconds
# Episode 48/200 - Total Reward: 1322
#  Retrying in 1 seconds
# Episode 49/200 - Total Reward: 1388
#  Retrying in 1 seconds
# Episode 50/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 51/200 - Total Reward: 1494
#  Retrying in 1 seconds
# Episode 52/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 53/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 54/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 55/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 56/200 - Total Reward: 1367
#  Retrying in 1 seconds
# Episode 57/200 - Total Reward: 1476
#  Retrying in 1 seconds
# Episode 58/200 - Total Reward: 1501
#  Retrying in 1 seconds
# Episode 59/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 60/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 61/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 62/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 63/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 64/200 - Total Reward: 1600
#  Retrying in 1 seconds
# Episode 65/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 66/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 67/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 68/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 69/200 - Total Reward: 1448
#  Retrying in 1 seconds
# Episode 70/200 - Total Reward: 1521
#  Retrying in 1 seconds
# Episode 71/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 72/200 - Total Reward: 1390
#  Retrying in 1 seconds
# Episode 73/200 - Total Reward: 1406
#  Retrying in 1 seconds
# Episode 74/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 75/200 - Total Reward: 1501
#  Retrying in 1 seconds
# Episode 76/200 - Total Reward: 1368
#  Retrying in 1 seconds
# Episode 77/200 - Total Reward: 1488
#  Retrying in 1 seconds
# Episode 78/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 79/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 80/200 - Total Reward: 1412
#  Retrying in 1 seconds
# Episode 81/200 - Total Reward: 1355
#  Retrying in 1 seconds
# Episode 82/200 - Total Reward: 1461
#  Retrying in 1 seconds
# Episode 83/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 84/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 85/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 86/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 87/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 88/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 89/200 - Total Reward: 1334
#  Retrying in 1 seconds
# Episode 90/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 91/200 - Total Reward: 1357
#  Retrying in 1 seconds
# Episode 92/200 - Total Reward: 1396
#  Retrying in 1 seconds
# Episode 93/200 - Total Reward: 1413
#  Retrying in 1 seconds
# Episode 94/200 - Total Reward: 1122
#  Retrying in 1 seconds
# Episode 95/200 - Total Reward: 583
#  Retrying in 1 seconds
# Episode 96/200 - Total Reward: 1256
#  Retrying in 1 seconds
# Episode 97/200 - Total Reward: 1392
#  Retrying in 1 seconds
# Episode 98/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 99/200 - Total Reward: 1499
#  Retrying in 1 seconds
# Episode 100/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 101/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 102/200 - Total Reward: 1286
#  Retrying in 1 seconds
# Episode 103/200 - Total Reward: 1301
#  Retrying in 1 seconds
# Episode 104/200 - Total Reward: 1341
#  Retrying in 1 seconds
# Episode 105/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 106/200 - Total Reward: 1465
#  Retrying in 1 seconds
# Episode 107/200 - Total Reward: 1356
#  Retrying in 1 seconds
# Episode 108/200 - Total Reward: 1346
#  Retrying in 1 seconds
# Episode 109/200 - Total Reward: 1441
#  Retrying in 1 seconds
# Episode 110/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 111/200 - Total Reward: 1462
#  Retrying in 1 seconds
# Episode 112/200 - Total Reward: 1508
#  Retrying in 1 seconds
# Episode 113/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 114/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 115/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 116/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 117/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 118/200 - Total Reward: 1345
#  Retrying in 1 seconds
# Episode 119/200 - Total Reward: 1545
#  Retrying in 1 seconds
# Episode 120/200 - Total Reward: 1330
#  Retrying in 1 seconds
# Episode 121/200 - Total Reward: 1324
#  Retrying in 1 seconds
# Episode 122/200 - Total Reward: 1409
#  Retrying in 1 seconds
# Episode 123/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 124/200 - Total Reward: 1420
#  Retrying in 1 seconds
# Episode 125/200 - Total Reward: 1297
#  Retrying in 1 seconds
# Episode 126/200 - Total Reward: 1330
#  Retrying in 1 seconds
# Episode 127/200 - Total Reward: 1377
#  Retrying in 1 seconds
# Episode 128/200 - Total Reward: 1492
#  Retrying in 1 seconds
# Episode 129/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 130/200 - Total Reward: 1540
#  Retrying in 1 seconds
# Episode 131/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 132/200 - Total Reward: 1476
#  Retrying in 1 seconds
# Episode 133/200 - Total Reward: 1509
#  Retrying in 1 seconds
# Episode 134/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 135/200 - Total Reward: 1478
#  Retrying in 1 seconds
# Episode 136/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 137/200 - Total Reward: 1483
#  Retrying in 1 seconds
# Episode 138/200 - Total Reward: 1477
#  Retrying in 1 seconds
# Episode 139/200 - Total Reward: 987
#  Retrying in 1 seconds
# Episode 140/200 - Total Reward: 617
#  Retrying in 1 seconds
# Episode 141/200 - Total Reward: 1375
#  Retrying in 1 seconds
# Episode 142/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 143/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 144/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 145/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 146/200 - Total Reward: 1515
#  Retrying in 1 seconds
# Episode 147/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 148/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 149/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 150/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 151/200 - Total Reward: 1445
#  Retrying in 1 seconds
# Episode 152/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 153/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 154/200 - Total Reward: 1515
#  Retrying in 1 seconds
# Episode 155/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 156/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 157/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 158/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 159/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 160/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 161/200 - Total Reward: 1472
#  Retrying in 1 seconds
# Episode 162/200 - Total Reward: 1512
#  Retrying in 1 seconds
# Episode 163/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 164/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 165/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 166/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 167/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 168/200 - Total Reward: 1471
#  Retrying in 1 seconds
# Episode 169/200 - Total Reward: 1473
#  Retrying in 1 seconds
# Episode 170/200 - Total Reward: 1451
#  Retrying in 1 seconds
# Episode 171/200 - Total Reward: 1480
#  Retrying in 1 seconds
# Episode 172/200 - Total Reward: 1394
#  Retrying in 1 seconds
# Episode 173/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 174/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 175/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 176/200 - Total Reward: 1451
#  Retrying in 1 seconds
# Episode 177/200 - Total Reward: 1486
#  Retrying in 1 seconds
# Episode 178/200 - Total Reward: 1508
#  Retrying in 1 seconds
# Episode 179/200 - Total Reward: 1476
#  Retrying in 1 seconds
# Episode 180/200 - Total Reward: 1357
#  Retrying in 1 seconds
# Episode 181/200 - Total Reward: 1366
#  Retrying in 1 seconds
# Episode 182/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 183/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 184/200 - Total Reward: 1474
#  Retrying in 1 seconds
# Episode 185/200 - Total Reward: 1358
#  Retrying in 1 seconds
# Episode 186/200 - Total Reward: 1376
#  Retrying in 1 seconds
# Episode 187/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 188/200 - Total Reward: 1476
#  Retrying in 1 seconds
# Episode 189/200 - Total Reward: 1357
#  Retrying in 1 seconds
# Episode 190/200 - Total Reward: 1357
#  Retrying in 1 seconds
# Episode 191/200 - Total Reward: 1404
#  Retrying in 1 seconds
# Episode 192/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 193/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 194/200 - Total Reward: 1439
#  Retrying in 1 seconds
# Episode 195/200 - Total Reward: 1325
#  Retrying in 1 seconds
# Episode 196/200 - Total Reward: 1406
#  Retrying in 1 seconds
# Episode 197/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 198/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 199/200 - Total Reward: 1479
#  Retrying in 1 seconds
# Episode 200/200 - Total Reward: 1316
#  Retrying in 1 seconds
# Evaluation Total Reward: 1462
# Average Ramp Waiting Time: 4.62 seconds
# Traffic Flow Efficiency (Vehicles/hour): 6.91

# %%
# Visualization: Total Reward per Episode
def plot_smoothed_rewards(rewards, window=10):
    smoothed_rewards = np.convolve(rewards, np.ones(window)/window, mode='valid')
    plt.figure()
    plt.plot(range(len(smoothed_rewards)), smoothed_rewards, label="Smoothed Rewards")
    plt.plot(range(len(rewards)), rewards, alpha=0.3, label="Original Rewards")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Total Reward per Episode (Smoothed)")
    plt.legend()
    plt.show()

# %%
plot_smoothed_rewards(rewards_per_episode, window=10)
